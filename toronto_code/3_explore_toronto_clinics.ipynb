# %%
import pandas as pd
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt

# %%
clinics_gdf = gpd.read_file('/Users/shivyucel/Documents/projects.nosync/opioid_accessibility/opioid_accessibility/data/toronto_data/clean_files/clean_clinics/clean_clinics_v3.shp')

# %%
clinics_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
clinics_gdf.to_crs(epsg=3857, inplace=True)
fig, ax = plt.subplots(figsize = (20, 10))
clinics_gdf.plot(ax=ax,markersize=100, color='red', alpha = 0.7)
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3d2904eede1d> in <module>
# ----> 1 clinics_clean = clinic_gdf[['site', 'lat', 'lon']]
#
# NameError: name 'clinic_gdf' is not defined
